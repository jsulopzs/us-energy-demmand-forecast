# %% [markdown]
# ## Load data

# %%
import pandas as pd

# %%
df_base = pd.read_csv('../data/pjm_pivot.csv', index_col=0, parse_dates=True)
regions = df_base.columns
df_base.head()
# Out:
#                        AE    AEP    AP  ATSI    BC     CE   DAY  DEOK    DOM  \
# period
# 2018-07-01 05:00:00  1301  12187  4384  6960  3134  12136  1619  2895   9775
# 2018-07-01 06:00:00  1314  11946  4391  6762  3139  11872  1605  2857   9787
# 2018-07-01 07:00:00  1410  12664  4757  6670  3377  11992  1707  2997  10453
# 2018-07-01 08:00:00  1567  14069  5308  7065  3788  12860  1916  3331  11734
# 2018-07-01 09:00:00  1749  15610  5862  7833  4262  14212  2145  3703  13084
#
#                       DPL   DUQ  EKPC    JC    ME    PE   PEP    PL    PN  \
# period
# 2018-07-01 05:00:00  1919  1466  1209  2388  1442  4397  3165  3835  1611
# 2018-07-01 06:00:00  1950  1455  1197  2416  1465  4423  3156  3901  1641
# 2018-07-01 07:00:00  2160  1528  1273  2644  1605  4743  3332  4232  1728
# 2018-07-01 08:00:00  2470  1688  1472  3064  1784  5230  3679  4613  1899
# 2018-07-01 09:00:00  2765  1875  1656  3569  1972  5752  4085  5014  2055
#
#                        PS  RECO
# period
# 2018-07-01 05:00:00  5009   186
# 2018-07-01 06:00:00  4990   187
# 2018-07-01 07:00:00  5267   202
# 2018-07-01 08:00:00  5735   230
# 2018-07-01 09:00:00  6299   259

# %% [markdown]
# ## Papermill

# %%
import papermill as pm

# %%
region = regions[0]

# %%
region
# Out:
# 'AE'

# %%
list_except = []

# %%
for region in regions:
    try:
        pm.execute_notebook(
            'Modelling.ipynb',
            f'outputs/{region}.ipynb',
            parameters=dict(region=region)
        )
    except Exception as e:
        print(e)
        list_except.append(region)
# Out:
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.40cell/s]2023-11-26 17:46:52.479585: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [03:11<00:00,  6.39s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  6.88cell/s]2023-11-26 17:50:04.218326: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [03:58<00:00,  7.95s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.67cell/s]2023-11-26 17:54:02.567114: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [03:57<00:00,  7.92s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.25cell/s]2023-11-26 17:58:00.271719: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [02:19<00:00,  4.64s/cell]
# Executing:  47%|████▋     | 14/30 [00:02<00:01,  9.51cell/s]2023-11-26 18:00:18.356084: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [02:54<00:00,  5.81s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  6.23cell/s]2023-11-26 18:03:13.908105: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [04:01<00:00,  8.06s/cell]
# Executing:  50%|█████     | 15/30 [00:03<00:01,  7.51cell/s]2023-11-26 18:07:15.480731: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [03:29<00:00,  6.99s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  6.69cell/s]2023-11-26 18:10:45.616224: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [01:59<00:00,  3.98s/cell]
# Executing:  50%|█████     | 15/30 [00:02<00:01,  8.94cell/s]2023-11-26 18:12:44.200506: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [01:24<00:00,  2.80s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.32cell/s]2023-11-26 18:14:08.559119: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [02:57<00:00,  5.93s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.11cell/s]2023-11-26 18:17:06.546239: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [02:17<00:00,  4.59s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.34cell/s]2023-11-26 18:19:24.165074: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [00:58<00:00,  1.94s/cell]
# Executing:  53%|█████▎    | 16/30 [00:03<00:01,  8.73cell/s]2023-11-26 18:20:22.285782: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [01:32<00:00,  3.07s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.20cell/s]2023-11-26 18:21:54.619166: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [02:13<00:00,  4.46s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.03cell/s]2023-11-26 18:24:08.258150: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [02:00<00:00,  4.02s/cell]
# Executing:  50%|█████     | 15/30 [00:02<00:01,  8.44cell/s]2023-11-26 18:26:08.498322: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [03:01<00:00,  6.04s/cell]
# Executing:  50%|█████     | 15/30 [00:02<00:01, 10.81cell/s]2023-11-26 18:29:09.070267: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [03:08<00:00,  6.29s/cell]
# Executing:  47%|████▋     | 14/30 [00:02<00:02,  7.85cell/s]2023-11-26 18:32:18.217254: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [03:17<00:00,  6.60s/cell]
# Executing:  50%|█████     | 15/30 [00:03<00:01,  8.33cell/s]2023-11-26 18:35:36.737449: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [01:51<00:00,  3.73s/cell]
# Executing:  47%|████▋     | 14/30 [00:03<00:02,  7.12cell/s]2023-11-26 18:37:28.741790: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Executing: 100%|██████████| 30/30 [02:39<00:00,  5.32s/cell]
